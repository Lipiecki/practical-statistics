# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Download CSV dataset about diet and losing weight. You can use this link:
# WeightLoss.csv . Some descriptions can be found here: WeightLoss.html .
# Create a DataFrame structure called df. Print its first 20 rows. The rest of the exercises
# refer to this data structure.

# %%
df = pd.read_csv('WeightLoss.csv', sep = ',')
df = df.drop(df.columns[0], axis = 1)
df.head(20)
# Out:
#       group  wl1  wl2  wl3  se1  se2  se3
# 0   Control    4    3    3   14   13   15
# 1   Control    4    4    3   13   14   17
# 2   Control    4    3    1   17   12   16
# 3   Control    3    2    1   11   11   12
# 4   Control    5    3    2   16   15   14
# 5   Control    6    5    4   17   18   18
# 6   Control    6    5    4   17   16   19
# 7   Control    5    4    1   13   15   15
# 8   Control    5    4    1   14   14   15
# 9   Control    3    3    2   14   15   13
# 10  Control    4    2    2   16   16   11
# 11  Control    5    2    1   15   13   16
# 12     Diet    6    3    2   12   11   14
# 13     Diet    5    4    1   13   14   15
# 14     Diet    7    6    3   17   11   18
# 15     Diet    6    4    2   16   15   18
# 16     Diet    3    2    1   16   17   15
# 17     Diet    5    5    4   13   11   18
# 18     Diet    4    3    1   12   11   14
# 19     Diet    4    2    1   12   11   11

# %% [markdown]
# 2. Find the number of observations (rows) and the number of attributes (columns). Find
# the basic statistics for weight loss in the first month (max, min, std, ...). HINT: use
# describe.

# %%
n_rows = df.shape[0]
n_columns = df.shape[1]
print('Number of rows: ', n_rows)
print('Number of columns: ', n_columns)

df["wl1"].describe()
# Out:
# Number of rows:  34
# Number of columns:  7
# count    34.000000
# mean      5.294118
# std       1.679275
# min       3.000000
# 25%       4.000000
# 50%       5.000000
# 75%       6.000000
# max       9.000000
# Name: wl1, dtype: float64

# %% [markdown]
# 3. Find the person with maximal total weight loss.

# %%
idx = df[['wl1', 'wl2', 'wl3']].sum(axis=1).idxmax()
df.iloc[idx]
# Out:
# group           DietEx
# wl1                  7
# wl2                  9
# wl3                  4
# se1                 16
# se2                 16
# se3                 19
# average_se        17.0
# Stable           False
# Total               20
# average_wl    6.666667
# Category             3
# Name: 32, dtype: object

# %% [markdown]
# 4. Find the person with minimal average self-esteem.

# %%
df[['se1', 'se2', 'se3']].sum(axis=1).idxmin()
# Out:
# 3

# %% [markdown]
# 5. Sort the rows by weight loss in the second month in descending order.

# %%
df.sort_values(by=['wl2'], ascending=False)
# Out:
#       group  wl1  wl2  wl3  se1  se2  se3
# 32   DietEx    7    9    4   16   16   19
# 26   DietEx    9    7    3   13   12   17
# 25   DietEx    4    7    1   16   12   18
# 24   DietEx    7    7    4   15   11   19
# 33   DietEx    8    6    1   17   17   17
# 14     Diet    7    6    3   17   11   18
# 30   DietEx    6    6    3   15   13   18
# 21     Diet    7    6    4   19   19   19
# 31   DietEx    9    5    2   16   14   17
# 29   DietEx    6    5    2   15   12   18
# 28   DietEx    3    5    1   13   13   16
# 20     Diet    6    5    3   17   16   19
# 17     Diet    5    5    4   13   11   18
# 5   Control    6    5    4   17   18   18
# 6   Control    6    5    4   17   16   19
# 13     Diet    5    4    1   13   14   15
# 8   Control    5    4    1   14   14   15
# 27   DietEx    3    4    1   16   13   17
# 7   Control    5    4    1   13   15   15
# 23     Diet    7    4    3   16   14   18
# 1   Control    4    4    3   13   14   17
# ...

# %% [markdown]
# 6. Print all the rows such that at least one weight loss was higher than 4.

# %%
#df.where((df['wl1'] > 4) | (df['wl2'] > 4) | (df['wl3'] > 4)).dropna()
df[(df['wl1'] > 4) | (df['wl2'] > 4) | (df['wl3'] > 4)]
# Out:
#       group  wl1  wl2  wl3  se1  se2  se3  average_se  Stable  Total  \
# 4   Control    5    3    2   16   15   14   15.000000   False     10
# 5   Control    6    5    4   17   18   18   17.666667   False     15
# 6   Control    6    5    4   17   16   19   17.333333   False     15
# 7   Control    5    4    1   13   15   15   14.333333   False     10
# 8   Control    5    4    1   14   14   15   14.333333   False     10
# 11  Control    5    2    1   15   13   16   14.666667   False      8
# 12     Diet    6    3    2   12   11   14   12.333333   False     11
# 13     Diet    5    4    1   13   14   15   14.000000   False     10
# 14     Diet    7    6    3   17   11   18   15.333333   False     16
# 15     Diet    6    4    2   16   15   18   16.333333   False     12
# 17     Diet    5    5    4   13   11   18   14.000000   False     14
# 20     Diet    6    5    3   17   16   19   17.333333   False     14
# 21     Diet    7    6    4   19   19   19   19.000000    True     17
# ...

# %% [markdown]
# 7. Add a column that contains average self-esteem

# %%
df["average_se"] = df[['se1', 'se2', 'se3']].mean(axis=1)
df
# Out:
#       group  wl1  wl2  wl3  se1  se2  se3  average_se
# 0   Control    4    3    3   14   13   15   14.000000
# 1   Control    4    4    3   13   14   17   14.666667
# 2   Control    4    3    1   17   12   16   15.000000
# 3   Control    3    2    1   11   11   12   11.333333
# 4   Control    5    3    2   16   15   14   15.000000
# 5   Control    6    5    4   17   18   18   17.666667
# 6   Control    6    5    4   17   16   19   17.333333
# 7   Control    5    4    1   13   15   15   14.333333
# 8   Control    5    4    1   14   14   15   14.333333
# 9   Control    3    3    2   14   15   13   14.000000
# 10  Control    4    2    2   16   16   11   14.333333
# 11  Control    5    2    1   15   13   16   14.666667
# 12     Diet    6    3    2   12   11   14   12.333333
# 13     Diet    5    4    1   13   14   15   14.000000
# 14     Diet    7    6    3   17   11   18   15.333333
# 15     Diet    6    4    2   16   15   18   16.333333
# ...

# %% [markdown]
# 8. List all the rows with the average self-esteem in the range [12 - 15]

# %%
df[(df['average_se'] >= 12) & (df['average_se'] <= 15)]
# Out:
#       group  wl1  wl2  wl3  se1  se2  se3  average_se
# 0   Control    4    3    3   14   13   15   14.000000
# 1   Control    4    4    3   13   14   17   14.666667
# 2   Control    4    3    1   17   12   16   15.000000
# 4   Control    5    3    2   16   15   14   15.000000
# 7   Control    5    4    1   13   15   15   14.333333
# 8   Control    5    4    1   14   14   15   14.333333
# 9   Control    3    3    2   14   15   13   14.000000
# 10  Control    4    2    2   16   16   11   14.333333
# 11  Control    5    2    1   15   13   16   14.666667
# 12     Diet    6    3    2   12   11   14   12.333333
# 13     Diet    5    4    1   13   14   15   14.000000
# 17     Diet    5    5    4   13   11   18   14.000000
# 18     Diet    4    3    1   12   11   14   12.333333
# 22     Diet    4    3    2   15   15   15   15.000000
# 24   DietEx    7    7    4   15   11   19   15.000000
# 26   DietEx    9    7    3   13   12   17   14.000000
# ...

# %% [markdown]
# 9. Print all the rows such that at least one weight loss was higher than 3 and self-esteem this month was at least 13

# %%
df.where(((df['wl1'] > 3) & (df['se1'] >= 13)) | \
    ((df['wl2'] > 3) & (df['se2'] >=13)) | ((df['wl3'] > 3) & (df['se3'] >=13))) \
    .dropna()
# Out:
#       group  wl1  wl2  wl3   se1   se2   se3  average_se
# 0   Control  4.0  3.0  3.0  14.0  13.0  15.0   14.000000
# 1   Control  4.0  4.0  3.0  13.0  14.0  17.0   14.666667
# 2   Control  4.0  3.0  1.0  17.0  12.0  16.0   15.000000
# 4   Control  5.0  3.0  2.0  16.0  15.0  14.0   15.000000
# 5   Control  6.0  5.0  4.0  17.0  18.0  18.0   17.666667
# 6   Control  6.0  5.0  4.0  17.0  16.0  19.0   17.333333
# 7   Control  5.0  4.0  1.0  13.0  15.0  15.0   14.333333
# 8   Control  5.0  4.0  1.0  14.0  14.0  15.0   14.333333
# 10  Control  4.0  2.0  2.0  16.0  16.0  11.0   14.333333
# 11  Control  5.0  2.0  1.0  15.0  13.0  16.0   14.666667
# 13     Diet  5.0  4.0  1.0  13.0  14.0  15.0   14.000000
# 14     Diet  7.0  6.0  3.0  17.0  11.0  18.0   15.333333
# 15     Diet  6.0  4.0  2.0  16.0  15.0  18.0   16.333333
# 17     Diet  5.0  5.0  4.0  13.0  11.0  18.0   14.000000
# 20     Diet  6.0  5.0  3.0  17.0  16.0  19.0   17.333333
# ...

# %% [markdown]
# 10. Set index to the group column

# %%
df10 = df.set_index('group', inplace = False)
df10
# Out:
#          wl1  wl2  wl3  se1  se2  se3  average_se
# group
# Control    4    3    3   14   13   15   14.000000
# Control    4    4    3   13   14   17   14.666667
# Control    4    3    1   17   12   16   15.000000
# Control    3    2    1   11   11   12   11.333333
# Control    5    3    2   16   15   14   15.000000
# Control    6    5    4   17   18   18   17.666667
# Control    6    5    4   17   16   19   17.333333
# Control    5    4    1   13   15   15   14.333333
# Control    5    4    1   14   14   15   14.333333
# Control    3    3    2   14   15   13   14.000000
# Control    4    2    2   16   16   11   14.333333
# Control    5    2    1   15   13   16   14.666667
# Diet       6    3    2   12   11   14   12.333333
# Diet       5    4    1   13   14   15   14.000000
# Diet       7    6    3   17   11   18   15.333333
# Diet       6    4    2   16   15   18   16.333333
# Diet       3    2    1   16   17   15   16.000000
# Diet       5    5    4   13   11   18   14.000000
# ...

# %% [markdown]
# 11. Set the index to the self-esteem in the 1st month. List all the rows with the index between 13 and 15 using loc.

# %%
df11 = df.set_index('se1', inplace=False)
df11.loc[(df11.index >= 13) & (df11.index <= 15)]
# Out:
#        group  wl1  wl2  wl3  se2  se3  average_se
# se1
# 14   Control    4    3    3   13   15   14.000000
# 13   Control    4    4    3   14   17   14.666667
# 13   Control    5    4    1   15   15   14.333333
# 14   Control    5    4    1   14   15   14.333333
# 14   Control    3    3    2   15   13   14.000000
# 15   Control    5    2    1   13   16   14.666667
# 13      Diet    5    4    1   14   15   14.000000
# 13      Diet    5    5    4   11   18   14.000000
# 15      Diet    4    3    2   15   15   15.000000
# 15    DietEx    7    7    4   11   19   15.000000
# 13    DietEx    9    7    3   12   17   14.000000
# 13    DietEx    3    5    1   13   16   14.000000
# 15    DietEx    6    5    2   12   18   15.000000
# 15    DietEx    6    6    3   13   18   15.333333

# %% [markdown]
# 12. Sort the rows by self-esteem in the 1st month and self esteem and the 2nd level. List all the rows with self-esteem in the first two months above 4

# %%
df12 = df.sort_values(by=['se1', 'se2'], ascending=False).reset_index(drop=True)
df12 = df12[(df12['se1'] > 13) & (df12['se2'] > 13)]
df12
# Out:
#       group  wl1  wl2  wl3  se1  se2  se3  average_se
# 0      Diet    7    6    4   19   19   19   19.000000
# 1   Control    6    5    4   17   18   18   17.666667
# 2    DietEx    8    6    1   17   17   17   17.000000
# 3   Control    6    5    4   17   16   19   17.333333
# 4      Diet    6    5    3   17   16   19   17.333333
# 7      Diet    3    2    1   16   17   15   16.000000
# 8   Control    4    2    2   16   16   11   14.333333
# 9    DietEx    7    9    4   16   16   19   17.000000
# 10  Control    5    3    2   16   15   14   15.000000
# 11     Diet    6    4    2   16   15   18   16.333333
# 12     Diet    7    4    3   16   14   18   16.000000
# 13   DietEx    9    5    2   16   14   17   15.666667
# 16     Diet    4    3    2   15   15   15   15.000000
# 21  Control    3    3    2   14   15   13   14.000000
# 22  Control    5    4    1   14   14   15   14.333333

# %% [markdown]
# 13. Add a column "Stable" that is True if and only if the self-esteem does not change in time

# %%
df["Stable"] = (df["se1"] == df["se2"]) & (df["se2"] == df["se3"])

# %% [markdown]
# 14. Find the number of rows in each group wherein the self-esteem in the 1st month is higher than the self-esteem in the 3rd month

# %%
df[df['se1'] > df['se3']].groupby('group').count()
# Out:
#          wl1  wl2  wl3  se1  se2  se3  average_se  Stable
# group
# Control    4    4    4    4    4    4           4       4
# Diet       2    2    2    2    2    2           2       2

# %%
df
# Out:
#       group  wl1  wl2  wl3  se1  se2  se3  average_se  Stable  Total  \
# 0   Control    4    3    3   14   13   15   14.000000   False     10
# 1   Control    4    4    3   13   14   17   14.666667   False     11
# 2   Control    4    3    1   17   12   16   15.000000   False      8
# 3   Control    3    2    1   11   11   12   11.333333   False      6
# 4   Control    5    3    2   16   15   14   15.000000   False     10
# 5   Control    6    5    4   17   18   18   17.666667   False     15
# 6   Control    6    5    4   17   16   19   17.333333   False     15
# 7   Control    5    4    1   13   15   15   14.333333   False     10
# 8   Control    5    4    1   14   14   15   14.333333   False     10
# 9   Control    3    3    2   14   15   13   14.000000   False      8
# 10  Control    4    2    2   16   16   11   14.333333   False      8
# 11  Control    5    2    1   15   13   16   14.666667   False      8
# 12     Diet    6    3    2   12   11   14   12.333333   False     11
# ...

# %% [markdown]
# 15. Draw a histogram of the total weight loss for each group

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#draw a histogram of the total weight loss for each group
df['Total'] = df[['wl1', 'wl2', 'wl3']].sum(axis=1)

groupname = df['group'].unique().tolist()
sns.histplot(df, x = 'Total', kde=True, bins = 25, hue = 'group')

plt.show()

# %% [markdown]
# 16. Remove all the information about the first month

# %%
df16 = df.drop(columns=['wl1', 'se1', 'average_se', 'Stable', 'Total'], inplace=False)
df16
# Out:
#       group  wl2  wl3  se2  se3
# 0   Control    3    3   13   15
# 1   Control    4    3   14   17
# 2   Control    3    1   12   16
# 3   Control    2    1   11   12
# 4   Control    3    2   15   14
# 5   Control    5    4   18   18
# 6   Control    5    4   16   19
# 7   Control    4    1   15   15
# 8   Control    4    1   14   15
# 9   Control    3    2   15   13
# 10  Control    2    2   16   11
# 11  Control    2    1   13   16
# 12     Diet    3    2   11   14
# 13     Diet    4    1   14   15
# 14     Diet    6    3   11   18
# 15     Diet    4    2   15   18
# 16     Diet    2    1   17   15
# 17     Diet    5    4   11   18
# 18     Diet    3    1   11   14
# 19     Diet    2    1   11   11
# 20     Diet    5    3   16   19
# 21     Diet    6    4   19   19
# 22     Diet    3    2   15   15
# 23     Diet    4    3   14   18
# 24   DietEx    7    4   11   19
# 25   DietEx    7    1   12   18
# 26   DietEx    7    3   12   17
# 27   DietEx    4    1   13   17
# ...

# %% [markdown]
# 17. Remove all the rows realted to the Control group

# %%
df17 = df[df['group'] != 'Control']
df17
# Out:
#      group  wl1  wl2  wl3  se1  se2  se3  average_se  Stable  Total
# 12    Diet    6    3    2   12   11   14   12.333333   False     11
# 13    Diet    5    4    1   13   14   15   14.000000   False     10
# 14    Diet    7    6    3   17   11   18   15.333333   False     16
# 15    Diet    6    4    2   16   15   18   16.333333   False     12
# 16    Diet    3    2    1   16   17   15   16.000000   False      6
# 17    Diet    5    5    4   13   11   18   14.000000   False     14
# 18    Diet    4    3    1   12   11   14   12.333333   False      8
# 19    Diet    4    2    1   12   11   11   11.333333   False      7
# 20    Diet    6    5    3   17   16   19   17.333333   False     14
# 21    Diet    7    6    4   19   19   19   19.000000    True     17
# 22    Diet    4    3    2   15   15   15   15.000000    True      9
# 23    Diet    7    4    3   16   14   18   16.000000   False     14
# 24  DietEx    7    7    4   15   11   19   15.000000   False     18
# ...

# %% [markdown]
# 18. Remove all the rows suspected to represent the same persone (with the same weight)

# %%
df18 = df.drop_duplicates(subset = ['wl1', 'wl2', 'wl3'], keep = 'first', inplace=False)
df18
# Out:
#       group  wl1  wl2  wl3  se1  se2  se3  average_se  Stable  Total
# 0   Control    4    3    3   14   13   15   14.000000   False     10
# 1   Control    4    4    3   13   14   17   14.666667   False     11
# 2   Control    4    3    1   17   12   16   15.000000   False      8
# 3   Control    3    2    1   11   11   12   11.333333   False      6
# 4   Control    5    3    2   16   15   14   15.000000   False     10
# 5   Control    6    5    4   17   18   18   17.666667   False     15
# 7   Control    5    4    1   13   15   15   14.333333   False     10
# 9   Control    3    3    2   14   15   13   14.000000   False      8
# 10  Control    4    2    2   16   16   11   14.333333   False      8
# 11  Control    5    2    1   15   13   16   14.666667   False      8
# 12     Diet    6    3    2   12   11   14   12.333333   False     11
# 14     Diet    7    6    3   17   11   18   15.333333   False     16
# 15     Diet    6    4    2   16   15   18   16.333333   False     12
# ...

# %% [markdown]
# 19. Assign each row into one of three categories concerning the average self-esteem (below 13, between 13 and 14.5, and above 14.5). Using pivoting, find for each category and each group number of rows and the average weight loss.

# %%
cat = lambda x: 1 if (x < 13) else (2 if x <= 14.5 else 3) 
df['average_wl'] = df[['wl1', 'wl2', 'wl3']].mean(axis = 1)
df["Category"] = df['average_se'].apply(cat)
df19 = df[["group", "average_wl", "Category"]]
df19 = pd.pivot_table(df19, values = ['average_wl'], index = ['Category', 'group'],
    aggfunc = [np.mean, 'count'])
df19
# Out:
#                        mean      count
#                  average_wl average_wl
# Category group
# 1        Control   2.000000          1
#          Diet      2.888889          3
# 2        Control   3.066667          5
#          Diet      4.000000          2
#          DietEx    4.666667          2
# 3        Control   3.722222          6
#          Diet      4.190476          7
#          DietEx    4.875000          8

# %% [markdown]
# 20. What is the total weight loss of all the participants? Assume that a magician can turn lost kilograms into high-quality gold. Is it possible to buy each living person at least one donut for this gold?

# %%
gold_price_usd_per_g = 54.883
donut_price_usd = 1
pop = 8*(10**9)
n_donuts_per_person = gold_price_usd_per_g*1000*3*df['average_wl'].sum()/(pop*donut_price_usd)
print("How many donuts per person you can buy?", n_donuts_per_person)
# Out:
# How many donuts per person you can buy? 0.00275787075
